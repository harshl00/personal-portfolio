# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
plt.plot(data['Unit Price'], data['Profit'],label='Profit')
plt.plot(data['Unit Price'], data['Discount'],label='Discount')
plt.title("Profit and Discount")
plt.xlabel("Unit Price")
plt.ylabel("Scale")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
data.head(12)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# 5    24847         Medium      0.05        3.28           4.20           14
# 6    24848         Medium      0.05        3.58           1.63           14
# 7    18181       Critical      0.00        4.42           4.99           15
# 8    20925         Medium      0.01       35.94           6.66           15
# 9    26267           High      0.04        2.98           1.58           16
# 10   26268           High      0.05      115.99           2.50           16
# ...

# %%
print(data)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
plt.plot(data['Customer ID'], data['Profit'],label='Profit')
plt.plot(data['Customer ID'], data['Discount'],label='Discount')
plt.title("Profit and Discount")
plt.xlabel("customer")
plt.ylabel("Scale")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
plt.plot(data['Customer ID'], data['Discount'],label='Discount')

plt.title("Customer and Discount")
plt.xlabel("customer")
plt.ylabel("Discount")
plt.legend()
plt.show()

# %%
plt.plot(data['Customer ID'], data['Profit'],label='Discount')

plt.title("Customer and Profit")
plt.xlabel("customer")
plt.ylabel("Profit")
plt.legend()
plt.show()

# %%
val = data.groupby('Product Category')['Profit'].sum().sort_values(ascending=False).head()
val.head()
# Out:
# 0          4.5600
# 1       4390.3665
# 2        -53.8096
# 3        803.4705
# 4        -24.0300
#           ...
# 1947    -116.7600
# 1948    -160.9520
# 1949     -41.8700
# 1950     -24.7104
# 1951     349.4850
# Name: Profit, Length: 1936, dtype: float64

# %%
val = data.groupby('Product Category')['Profit'].sum().sort_values(ascending=False).head()
plt.figure(figsize=( 4,3))
plt.pie(val,labels=val.index, autopct='%1.1f%%')
plt.title('Profit per Product Category')
plt.show()

# %%
val = data.groupby('Product Category')['Profit'].sum()
# Out:
# Product Category
# Furniture          49515.527436
# Office Supplies    90204.715937
# Technology         75303.156364
# Name: Profit, dtype: float64

# %%
val = data.groupby('Product Category')['Profit'].sum().pct_change()
val
# Out:
# Product Category
# Furniture               NaN
# Office Supplies    0.821746
# Technology        -0.165197
# Name: Profit, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
plt.plot(data['Customer ID'], data['Order Priority'],label='Priority')
plt.title("Customer and Priority")
plt.xlabel("customer")
plt.ylabel("Priority")
plt.legend()
plt.show()

# %%
data=data[['Product Category','Profit','Sales']].copy()
data.head(31)
# Out:
#    Product Category      Profit    Sales
# 0   Office Supplies     4.56000    13.01
# 1         Furniture  4390.36650  6362.85
# 2         Furniture   -53.80960   211.15
# 3         Furniture   803.47050  1164.45
# 4   Office Supplies   -24.03000    22.23
# 5   Office Supplies   -37.03000    13.99
# 6   Office Supplies    -0.71000    14.26
# 7   Office Supplies   -59.82000    33.47
# 8   Office Supplies   261.87570   379.53
# 9   Office Supplies     2.63000    18.80
# 10       Technology   652.73310   945.99
# 11        Furniture   314.48130   455.77
# 12       Technology  -114.63990   231.79
# 13        Furniture   384.38000  1876.69
# 14  Office Supplies   -17.49000   293.06
# 15       Technology  -114.63990   914.29
# 16  Office Supplies   -28.29680    67.49
# 17  Office Supplies    -5.30720     2.25
# 18        Furniture     8.89400    54.78
# 19  Office Supplies   144.69000   424.68
# 20       Technology   -35.87880    40.17
# 21       Technology   209.99700   783.55
# ...

# %%
val = data.groupby('Product Category')['Profit'].sum().sort_values(ascending=False).head()
plt.figure(figsize=(4, 3))
plt.pie(val,labels=val.index, autopct='%1.1f%%')
plt.title('Profit per Product Category')
plt.show()

# %%
data["ProductC_OfficeSupplies"]=data['Product Category'].sum()
data.columns
data['show_columns']=data['Sales'].sum()
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.drop(columns=['show_columns'])
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
data.drop(columns=['Profit_RS'])
# Out:
#      Product Category     Profit  \
# 0     Office Supplies     4.5600
# 1           Furniture  4390.3665
# 2           Furniture   -53.8096
# 3           Furniture   803.4705
# 4     Office Supplies   -24.0300
# ...               ...        ...
# 1947  Office Supplies  -116.7600
# 1948       Technology  -160.9520
# 1949  Office Supplies   -41.8700
# 1950        Furniture   -24.7104
# 1951        Furniture   349.4850
#
#                                 ProductC_OfficeSupplies
# 0     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 1     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 2     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 3     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 4     Office SuppliesFurnitureFurnitureFurnitureOffi...
# ...                                                 ...
# 1947  Office SuppliesFurnitureFurnitureFurnitureOffi...
# 1948  Office SuppliesFurnitureFurnitureFurnitureOffi...
# ...

# %%
data['dailySales_Sum']=data['Sales'].sum()
print(data)
# Out:
#      Product Category     Profit    Sales  dailySales_Sum
# 0     Office Supplies     4.5600    13.01      1881524.77
# 1           Furniture  4390.3665  6362.85      1881524.77
# 2           Furniture   -53.8096   211.15      1881524.77
# 3           Furniture   803.4705  1164.45      1881524.77
# 4     Office Supplies   -24.0300    22.23      1881524.77
# ...               ...        ...      ...             ...
# 1947  Office Supplies  -116.7600   207.31      1881524.77
# 1948       Technology  -160.9520   143.12      1881524.77
# 1949  Office Supplies   -41.8700    59.98      1881524.77
# 1950        Furniture   -24.7104   135.78      1881524.77
# 1951        Furniture   349.4850   506.50      1881524.77
#
# [1936 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Product Category', 'Profit', 'ProductC_OfficeSupplies', 'Profit_RS'], dtype='object')

# %%
data.drop(columns=['Profit_RS'])
# Out:
#      Product Category     Profit  \
# 0     Office Supplies     4.5600
# 1           Furniture  4390.3665
# 2           Furniture   -53.8096
# 3           Furniture   803.4705
# 4     Office Supplies   -24.0300
# ...               ...        ...
# 1947  Office Supplies  -116.7600
# 1948       Technology  -160.9520
# 1949  Office Supplies   -41.8700
# 1950        Furniture   -24.7104
# 1951        Furniture   349.4850
#
#                                 ProductC_OfficeSupplies
# 0     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 1     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 2     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 3     Office SuppliesFurnitureFurnitureFurnitureOffi...
# 4     Office SuppliesFurnitureFurnitureFurnitureOffi...
# ...                                                 ...
# 1947  Office SuppliesFurnitureFurnitureFurnitureOffi...
# 1948  Office SuppliesFurnitureFurnitureFurnitureOffi...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data["ProductC_OfficeSupplies"]=data['Product Category'].sum()
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID',
#        'ProductC_OfficeSupplies'],
#       dtype='object')

# %%
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.drop(columns=['ProductC_OfficeSupplies'])
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID',
#        'ProductC_OfficeSupplies'],
#       dtype='object')

# %%
del data['dailySales_Sum']
data.head()
# Out:
#   Product Category     Profit    Sales
# 0  Office Supplies     4.5600    13.01
# 1        Furniture  4390.3665  6362.85
# 2        Furniture   -53.8096   211.15
# 3        Furniture   803.4705  1164.45
# 4  Office Supplies   -24.0300    22.23

# %%
del data['Sales']
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
'''
dropped_column = df.pop('C')  # Removes 'C' and returns it
print(df)
print(dropped_column)  # Shows the removed column
del df['A']  # Deletes column 'A'
print(df)
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
del data['City']
#print(data)
#df=data
#df.pop('ProductC_OfficeSupplies')
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Order ID', 'ProductC_OfficeSupplies',
#        'show_columns'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
plt.bar(data['Product Category'],data['Sales'],label='Sales')
plt.bar(data['Product Category'],data['Profit'],label='Profit')
plt.xlabel('Product Category')
plt.ylabel('Sales & Price')
plt.legend()
plt.show()

# %%
plt.hist(data['Shipping Cost'])
plt.show()

# %%
plt.bar(data['City'],data['Sales'],label='Sales')
plt.bar(data['City'],data['Profit'],label='Profit')
plt.xlabel('City')
plt.ylabel('Sales & Price')
plt.legend()
plt.show()

# %%
plt.hist(data['Customer Segment'])
plt.show()

# %%
data['Discount'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Sales'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.scatter(data['Sales'],data['Profit'])
plt.title('Distribution of Sales and Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
# !pip install  pywaffle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/25.6 MB ? eta -:--:--
#    -------- ------------------------------- 5.5/25.6 MB 30.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 11.0/25.6 MB 28.7 MB/s eta 0:00:01
#    -------------------------- ------------- 17.3/25.6 MB 28.7 MB/s eta 0:00:01
#    ------------------------------------- -- 24.1/25.6 MB 29.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.6/25.6 MB 28.0 MB/s eta 0:00:00
# ...

# %%
from pywaffle import Waffle
data ={'phone': ['Xiaomi', 'Samsung','Apple', 'Nokia', 'Realme'],
       'stock': [44, 12, 8, 5, 3]
     }
df = pd.DataFrame(data)
fig = plt.figure(
    FigureClass = Waffle,
    rows = 5,
    values = df.stock,
    labels = list(df.phone)
)
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
# Density Plot
import seaborn as sns
data = pd.read_excel("C:/Users/My PC/Downloads/sports/P6-SuperStoreUS-2015.xlsx")
data.head()
sns.histplot(data['Sales'], kde = True, color ='red', bins = 30).set_title('Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Histogram Plot')

# %%
sns.heatmap(data.corr(),annot=True,cmap='magma')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.heatmap(data.corr(),annot=True,cmap='magma')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.countplot(x='Ship Mode',data=data,palette='magma')
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_11636\1500809534.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ship Mode',data=data,palette='magma')
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
sns.lmplot(data=data, x="Unit Price", y="Profit", hue="Product Category")

# %%
sns.pairplot(data=data, hue="Customer ID")

# %%
pip install bokeh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data.dropna(inplace=True)

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show,output_notebook
output_notebook()
# create three plots with one renderer each
s1 = figure(width=250, height=250, background_fill_color="#fafafa")
s1.scatter(data['Sales'], data['Profit'], size=12, color="#53777a", alpha=0.8, marker="circle")
s2 = figure(width=250, height=250, background_fill_color="#fafafa")
s2.scatter(data['Sales'], data['Profit'], size=12, color="#c02942", alpha=0.8, marker="triangle")
s3 = figure(width=250, height=250, background_fill_color="#fafafa")
s3.scatter(data['Sales'], data['Profit'], size=12, color="#d95b43", alpha=0.8, marker="square")
# put the results in a row and show
show(row(s1, s2, s3))
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d3cccd2b-f1e1-423a-8057-412cb56cacd7">Loading BokehJS ...</span>
#     </div>
#   <div id="a594d5a2-8d51-49ae-859a-ee1616e9e618" data-root-id="p1130" style="display: contents;"></div>

# %%
p = figure(x_range=data['Ship Mode'].unique(), height=350, title="Ship Mode")  # define the categories on the x-axis
p.vbar(x=data['Ship Mode'], top=data['Shipping Cost'], width=0.9, color="firebrick")
show(p)
# Out:
#   <div id="f119fdf6-ca71-4a9c-84e3-e7cc18072499" data-root-id="p1137" style="display: contents;"></div>

# %%
from bokeh.io import curdoc
# curdoc().theme = "caliber"
# curdoc().theme = "dark_minimal"
curdoc().theme = "light_minimal"
#curdoc().theme = "night_sky"
# curdoc().theme = "contrast"
# create a plot
themed_plot = figure(sizing_mode="stretch_width", max_width=500, height=250)
themed_plot.line(data['Sales'], data['Profit'])
show(themed_plot)
# Out:
#   <div id="f1b9d584-73b8-488d-87ea-c17042770152" data-root-id="p1183" style="display: contents;"></div>

# %%
import xyzservices.providers as xyz
from bokeh.plotting import figure, show
# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(xyz.OpenStreetMap.Mapnik)
show(p)
# Out:
#   <div id="f7f4d118-d611-4a55-ae2d-9bf8edece5b9" data-root-id="p1228" style="display: contents;"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.util.hex import axial_to_cartesian
q = np.array([0,  0, 0, -1, -1,  1, 1])
r = np.array([0, -1, 1,  0,  1, -1, 0])
p = figure(width=400, height=400, toolbar_location=None)
p.grid.visible = False
p.hex_tile(q, r, size=1, fill_color=["firebrick"]*3 + ["navy"]*4,
           line_color="white", alpha=0.5)
x, y = axial_to_cartesian(q, r, 1, "pointytop")
p.text(x, y, text=[f"({q}, {r})" for (q, r) in zip(q, r)],
       text_baseline="middle", text_align="center")
show(p)
# Out:
#   <div id="dd83ac18-402b-4557-ae93-bfbcd7d94117" data-root-id="p1267" style="display: contents;"></div>

# %%
import numpy as np
from bokeh.models import HoverTool
from bokeh.plotting import figure, show
n = 500
x = 2 + 2*np.random.standard_normal(n)
y = 2 + 2*np.random.standard_normal(n)
p = figure(title="Hexbin for 500 points", match_aspect=True,tools="wheel_zoom,reset",
           background_fill_color='#440154')
p.grid.visible = False
r, bins = p.hexbin(x, y, size=0.5, hover_color="pink", hover_alpha=0.8)
p.circle(x, y, color="white", size=1)
p.add_tools(HoverTool(tooltips=[("count", "@c"), ("(q,r)", "(@q, @r)")],
    mode="mouse", point_policy="follow_mouse", renderers=[r]
))
show(p)
# Out:
# ...
#   <div id="bc4d4404-a857-4691-b1ba-6d2d6e81174f" data-root-id="p1323" style="display: contents;"></div>

# %%
pip install squarify matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify
import matplotlib.pyplot as plt
aggregated = data.groupby("Ship Mode").sum(numeric_only=True)
squarify.plot(sizes=aggregated['Shipping Cost'], label=data['Ship Mode'].unique())
plt.show()

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')
